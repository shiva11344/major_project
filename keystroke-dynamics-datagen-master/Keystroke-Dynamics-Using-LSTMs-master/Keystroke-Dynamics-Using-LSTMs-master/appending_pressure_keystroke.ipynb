# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('C://Users//user//Desktop//major_project//keystroke-dynamics-datagen-master//Keystroke-Dynamics-Using-LSTMs-master//Keystroke-Dynamics-Using-LSTMs-master/shiva_new.csv')
df2= pd.read_csv('C://Users//user//Desktop//major_project//keystroke-dynamics-datagen-master//Keystroke-Dynamics-Using-LSTMs-master//Keystroke-Dynamics-Using-LSTMs-master/pressure.csv')

# %%
print(df1.shape,"   ",df2.shape)
# Out:
# (1000, 29)     (1000, 5)

# %%
df_concat = pd.concat([df1, df2], axis=1)

# %%
df_concat
# Out:
#       Name  Session  Repetetion         a         b         c         d  \
# 0    shiva        1           1  0.149134  0.095284  0.244418  0.078049
# 1    shiva        1           2  0.120761  0.070547  0.191308  0.088534
# 2    shiva        1           3  0.140864  0.054410  0.195274  0.076005
# 3    shiva        1           4  0.129242  0.105580  0.234822  0.078046
# 4    shiva        1           5  0.118013  0.092016  0.210029  0.061421
# 5    shiva        1           6  0.134518  0.094014  0.228532  0.086808
# 6    shiva        1           7  0.127765  0.088740  0.216505  0.075840
# 7    shiva        1           8  0.127208  0.079946  0.207154  0.070740
# 8    shiva        1           9  0.121705  0.137158  0.258863  0.101566
# 9    shiva        1          10  0.129697  0.065921  0.195618  0.061359
# 10   shiva        2          11  0.119006  0.071574  0.190580  0.082229
# 11   shiva        2          12  0.132224  0.081134  0.213358  0.078557
# ...

# %%
df_concat.to_csv('C:\\Users\\user\\Desktop\\major_project\\keystroke-dynamics-datagen-master\\Keystroke-Dynamics-Using-LSTMs-master\\Keystroke-Dynamics-Using-LSTMs-master\\shiva_appended.csv',index=False)

# %%
df = pd.read_csv('C://Users//user//Desktop//major_project//keystroke-dynamics-datagen-master//Keystroke-Dynamics-Using-LSTMs-master//Keystroke-Dynamics-Using-LSTMs-master/shiva_appended.csv')

# %%
df
# Out:
#       Name  Session  Repetetion         a         b         c         d  \
# 0    shiva        1           1  0.149134  0.095284  0.244418  0.078049
# 1    shiva        1           2  0.120761  0.070547  0.191308  0.088534
# 2    shiva        1           3  0.140864  0.054410  0.195274  0.076005
# 3    shiva        1           4  0.129242  0.105580  0.234822  0.078046
# 4    shiva        1           5  0.118013  0.092016  0.210029  0.061421
# 5    shiva        1           6  0.134518  0.094014  0.228532  0.086808
# 6    shiva        1           7  0.127765  0.088740  0.216505  0.075840
# 7    shiva        1           8  0.127208  0.079946  0.207154  0.070740
# 8    shiva        1           9  0.121705  0.137158  0.258863  0.101566
# 9    shiva        1          10  0.129697  0.065921  0.195618  0.061359
# 10   shiva        2          11  0.119006  0.071574  0.190580  0.082229
# 11   shiva        2          12  0.132224  0.081134  0.213358  0.078557
# ...

# %%
df1 = pd.read_csv('C://Users//user//Desktop//major_project//keystroke-dynamics-datagen-master//Keystroke-Dynamics-Using-LSTMs-master//Keystroke-Dynamics-Using-LSTMs-master/shiva_fraud.csv')
df2= pd.read_csv('C://Users//user//Desktop//major_project//keystroke-dynamics-datagen-master//Keystroke-Dynamics-Using-LSTMs-master//Keystroke-Dynamics-Using-LSTMs-master/fraud_pressure.csv')

# %%
df1.shape
# Out:
# (400, 29)

# %%
df2.shape
# Out:
# (400, 5)

# %%
df_concat = pd.concat([df1, df2], axis=1)

# %%
df_concat
# Out:
#        Name  Session  Repetetion         a         b         c         d  \
# 0    fshiva        1           1  0.165581  0.078276  0.243857  0.146824
# 1    fshiva        1           2  0.140557  0.508879  0.649436  0.083952
# 2    fshiva        1           3  0.156596  0.403169  0.559765  0.073859
# 3    fshiva        1           4  0.143176  0.648242  0.791418  0.066525
# 4    fshiva        1           5  0.139343  0.355161  0.494504  0.070443
# 5    fshiva        1           6  0.134435  0.183401  0.317836  0.077139
# 6    fshiva        1           7  0.153799  0.366636  0.520435  0.077743
# 7    fshiva        1           8  0.119315  0.321975  0.441290  0.084874
# 8    fshiva        1           9  0.138519  0.530176  0.668695  0.048252
# 9    fshiva        1          10  0.166834  0.460473  0.627307  0.065617
# 10   fshiva        2          11  0.171424  0.216911  0.388335  0.172012
# 11   fshiva        2          12  0.161652  0.187839  0.349491  0.071358
# ...

# %%
df_concat.to_csv('C:\\Users\\user\\Desktop\\major_project\\keystroke-dynamics-datagen-master\\Keystroke-Dynamics-Using-LSTMs-master\\Keystroke-Dynamics-Using-LSTMs-master\\shiva_fraud_appended.csv',index=False)

# %%
# Out:
#        Name  Session  Repetetion         a         b         c         d  \
# 0    fshiva        1           1  0.165581  0.078276  0.243857  0.146824
# 1    fshiva        1           2  0.140557  0.508879  0.649436  0.083952
# 2    fshiva        1           3  0.156596  0.403169  0.559765  0.073859
# 3    fshiva        1           4  0.143176  0.648242  0.791418  0.066525
# 4    fshiva        1           5  0.139343  0.355161  0.494504  0.070443
# 5    fshiva        1           6  0.134435  0.183401  0.317836  0.077139
# 6    fshiva        1           7  0.153799  0.366636  0.520435  0.077743
# 7    fshiva        1           8  0.119315  0.321975  0.441290  0.084874
# 8    fshiva        1           9  0.138519  0.530176  0.668695  0.048252
# 9    fshiva        1          10  0.166834  0.460473  0.627307  0.065617
# 10   fshiva        2          11  0.171424  0.216911  0.388335  0.172012
# 11   fshiva        2          12  0.161652  0.187839  0.349491  0.071358
# ...

# %%
df=pd.read_csv('C:\\Users\\user\\Desktop\\major_project\\keystroke-dynamics-datagen-master\\Keystroke-Dynamics-Using-LSTMs-master\\Keystroke-Dynamics-Using-LSTMs-master\\shiva_fraud_appended.csv')

# %%
df
# Out:
#        Name  Session  Repetetion         a         b         c         d  \
# 0    fshiva        1           1  0.165581  0.078276  0.243857  0.146824
# 1    fshiva        1           2  0.140557  0.508879  0.649436  0.083952
# 2    fshiva        1           3  0.156596  0.403169  0.559765  0.073859
# 3    fshiva        1           4  0.143176  0.648242  0.791418  0.066525
# 4    fshiva        1           5  0.139343  0.355161  0.494504  0.070443
# 5    fshiva        1           6  0.134435  0.183401  0.317836  0.077139
# 6    fshiva        1           7  0.153799  0.366636  0.520435  0.077743
# 7    fshiva        1           8  0.119315  0.321975  0.441290  0.084874
# 8    fshiva        1           9  0.138519  0.530176  0.668695  0.048252
# 9    fshiva        1          10  0.166834  0.460473  0.627307  0.065617
# 10   fshiva        2          11  0.171424  0.216911  0.388335  0.172012
# 11   fshiva        2          12  0.161652  0.187839  0.349491  0.071358
# ...
