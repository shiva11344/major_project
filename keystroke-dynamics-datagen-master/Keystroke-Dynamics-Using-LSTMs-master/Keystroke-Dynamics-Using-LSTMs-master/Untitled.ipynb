# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('C://Users//user//Desktop//major_project//keystroke-dynamics-datagen-master//Keystroke-Dynamics-Using-LSTMs-master//Keystroke-Dynamics-Using-LSTMs-master/shiva_fraud.csv')
df
# Out:
#        Name  Session  Repetetion         a         b         c         d  \
# 0    fshiva        1           1  0.165581  0.078276  0.243857  0.146824
# 1    fshiva        1           2  0.140557  0.508879  0.649436  0.083952
# 2    fshiva        1           3  0.156596  0.403169  0.559765  0.073859
# 3    fshiva        1           4  0.143176  0.648242  0.791418  0.066525
# 4    fshiva        1           5  0.139343  0.355161  0.494504  0.070443
# 5    fshiva        1           6  0.134435  0.183401  0.317836  0.077139
# 6    fshiva        1           7  0.153799  0.366636  0.520435  0.077743
# 7    fshiva        1           8  0.119315  0.321975  0.441290  0.084874
# 8    fshiva        1           9  0.138519  0.530176  0.668695  0.048252
# 9    fshiva        1          10  0.166834  0.460473  0.627307  0.065617
# 10   fshiva        2          11  0.171424  0.216911  0.388335  0.172012
# 11   fshiva        2          12  0.161652  0.187839  0.349491  0.071358
# ...

# %%
from sklearn.utils import shuffle
df = shuffle(df)
df
# Out:
#        Name  Session  Repetetion         a         b         c         d  \
# 84   fshiva        9          85  0.150269  0.170220  0.320489  0.060723
# 96   fshiva       10          97  0.167887  0.425368  0.593255  0.089192
# 162  fshiva        9          85  0.150269  0.170220  0.320489  0.060723
# 168  fshiva        6          54  0.131335  0.195769  0.327104  0.058932
# 110  fshiva        7          64  0.149777  0.179005  0.328782  0.065056
# 180  fshiva        8          79  0.143797  0.226830  0.370627  0.075545
# 46   fshiva        5          47  0.138790  0.171213  0.310003  0.047443
# 169  fshiva       10          91  0.131268  0.320844  0.452112  0.069089
# 102  fshiva        7          67  0.166996  0.175603  0.342599  0.078764
# 104  fshiva        2          16  0.160611  0.159918  0.320529  0.061984
# 113  fshiva        1           6  0.134435  0.183401  0.317836  0.077139
# 52   fshiva        6          53  0.114793  0.266736  0.381529  0.076513
# ...

# %%
df.to_csv('C:\\Users\\user\\Desktop\\major_project\\keystroke-dynamics-datagen-master\\Keystroke-Dynamics-Using-LSTMs-master\\Keystroke-Dynamics-Using-LSTMs-master\\shiva_fraud.csv', mode='a', header=False,index=False)

# %%
df = pd.read_csv('C:\\Users\\user\\Desktop\\major_project\\keystroke-dynamics-datagen-master\\Keystroke-Dynamics-Using-LSTMs-master\\Keystroke-Dynamics-Using-LSTMs-master\\shiva_fraud.csv')
df
# Out:
#        Name  Session  Repetetion         a         b         c         d  \
# 0    fshiva        1           1  0.165581  0.078276  0.243857  0.146824
# 1    fshiva        1           2  0.140557  0.508879  0.649436  0.083952
# 2    fshiva        1           3  0.156596  0.403169  0.559765  0.073859
# 3    fshiva        1           4  0.143176  0.648242  0.791418  0.066525
# 4    fshiva        1           5  0.139343  0.355161  0.494504  0.070443
# 5    fshiva        1           6  0.134435  0.183401  0.317836  0.077139
# 6    fshiva        1           7  0.153799  0.366636  0.520435  0.077743
# 7    fshiva        1           8  0.119315  0.321975  0.441290  0.084874
# 8    fshiva        1           9  0.138519  0.530176  0.668695  0.048252
# 9    fshiva        1          10  0.166834  0.460473  0.627307  0.065617
# 10   fshiva        2          11  0.171424  0.216911  0.388335  0.172012
# 11   fshiva        2          12  0.161652  0.187839  0.349491  0.071358
# ...
